# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
data=pd.read_csv("abalone.csv")

# %%
df=data.head()

# %%
df
# Out:
#   Sex  Length  Diameter  Height  Wholweight  Shuckedweight  Visceraweight  \
# 0   M   0.455     0.365   0.095      0.5140         0.2245         0.1010
# 1   M   0.350     0.265   0.090      0.2255         0.0995         0.0485
# 2   F   0.530     0.420   0.135      0.6770         0.2565         0.1415
# 3   M   0.440     0.365   0.125      0.5160         0.2155         0.1140
# 4   I   0.330     0.255   0.080      0.2050         0.0895         0.0395
#
#    Shellweight  Rings
# 0        0.150     15
# 1        0.070      7
# 2        0.210      9
# 3        0.155     10
# 4        0.055      7

# %% [markdown]
# ### calculate +1.5 gives the age in years

# %%
age=1.5+data.Rings
data['age']=age

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Wholweight  Shuckedweight  Visceraweight  \
# 0   M   0.455     0.365   0.095      0.5140         0.2245         0.1010
# 1   M   0.350     0.265   0.090      0.2255         0.0995         0.0485
# 2   F   0.530     0.420   0.135      0.6770         0.2565         0.1415
# 3   M   0.440     0.365   0.125      0.5160         0.2155         0.1140
# 4   I   0.330     0.255   0.080      0.2050         0.0895         0.0395
#
#    Shellweight  Rings   age
# 0        0.150     15  16.5
# 1        0.070      7   8.5
# 2        0.210      9  10.5
# 3        0.155     10  11.5
# 4        0.055      7   8.5

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Wholweight  Shuckedweight  Visceraweight  \
# 4172   F   0.565     0.450   0.165      0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135      0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205      1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150      1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195      1.9485         0.9455         0.3765
#
#       Shellweight  Rings   age
# 4172       0.2490     11  12.5
# 4173       0.2605     10  11.5
# 4174       0.3080      9  10.5
# 4175       0.2960     10  11.5
# 4176       0.4950     12  13.5

# %% [markdown]
# # Perform the below visualization
#
# ## Univariate Analysis

# %%
sns.displot(data["Length"])

# %%
sns.displot(data["age"])

# %%
sns.boxplot(x=data.age)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
data.boxplot(column=['Rings'], grid=False,color='red')
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=['age'], grid=False, color='black')
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(data['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [markdown]
# ### Bi-Variate Analysis

# %%
sns.lineplot(x=data.age,y=data.Length)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Length'>

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=data.Height,y=data.Rings)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Rings'>

# %%
sns.scatterplot(x=data.age,y=data.Shuckedweight)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Shuckedweight'>

# %%
sns.pointplot(x=data.age,y=data.Height)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Height'>

# %%
sns.scatterplot(x=data.age,y=data.Length)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Length'>

# %%
sns.scatterplot(x=data.Length, y=data.Diameter)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Diameter'>

# %%
sns.lineplot(x=data.Height,y=data.Wholweight)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Wholweight'>

# %% [markdown]
# ### multivariate analysis

# %%
sns.pairplot(data=data[["Height","Length","Diameter"]])

# %%
sns.pairplot(data=data[["Wholweight","Shuckedweight","Rings","Shellweight"]])

# %% [markdown]
# ### Perform descriptive statistics on the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sex            4177 non-null   object
#  1   Length         4177 non-null   float64
#  2   Diameter       4177 non-null   float64
#  3   Height         4177 non-null   float64
#  4   Wholweight     4177 non-null   float64
#  5   Shuckedweight  4177 non-null   float64
#  6   Visceraweight  4177 non-null   float64
#  7   Shellweight    4177 non-null   float64
#  8   Rings          4177 non-null   int64
#  9   age            4177 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 326.5+ KB

# %%
data.describe()
# Out:
#             Length     Diameter       Height   Wholweight  Shuckedweight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000    4177.000000
# mean      0.523992     0.407881     0.139516     0.828742       0.359367
# std       0.120093     0.099240     0.041827     0.490389       0.221963
# min       0.075000     0.055000     0.000000     0.002000       0.001000
# 25%       0.450000     0.350000     0.115000     0.441500       0.186000
# 50%       0.545000     0.425000     0.140000     0.799500       0.336000
# 75%       0.615000     0.480000     0.165000     1.153000       0.502000
# max       0.815000     0.650000     1.130000     2.825500       1.488000
#
#        Visceraweight  Shellweight        Rings          age
# count    4177.000000  4177.000000  4177.000000  4177.000000
# mean        0.180594     0.238831     9.933684    11.433684
# std         0.109614     0.139203     3.224169     3.224169
# min         0.000500     0.001500     1.000000     2.500000
# ...

# %% [markdown]
# ## Check for Missing values and deal with them

# %%
data.isna().sum()
# Out:
# Sex              0
# Length           0
# Diameter         0
# Height           0
# Wholweight       0
# Shuckedweight    0
# Visceraweight    0
# Shellweight      0
# Rings            0
# age              0
# dtype: int64

# %% [markdown]
# ##  Find the outliers and replace them outliers

# %%
data.describe()
# Out:
#             Length     Diameter       Height   Wholweight  Shuckedweight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000    4177.000000
# mean      0.523992     0.407881     0.139516     0.828742       0.359367
# std       0.120093     0.099240     0.041827     0.490389       0.221963
# min       0.075000     0.055000     0.000000     0.002000       0.001000
# 25%       0.450000     0.350000     0.115000     0.441500       0.186000
# 50%       0.545000     0.425000     0.140000     0.799500       0.336000
# 75%       0.615000     0.480000     0.165000     1.153000       0.502000
# max       0.815000     0.650000     1.130000     2.825500       1.488000
#
#        Visceraweight  Shellweight        Rings          age
# count    4177.000000  4177.000000  4177.000000  4177.000000
# mean        0.180594     0.238831     9.933684    11.433684
# std         0.109614     0.139203     3.224169     3.224169
# min         0.000500     0.001500     1.000000     2.500000
# ...

# %%
outliers=data.quantile(q=(0.25,0.75))

# %%
outliers
# Out:
#       Length  Diameter  Height  Wholweight  Shuckedweight  Visceraweight  \
# 0.25   0.450      0.35   0.115      0.4415          0.186         0.0935
# 0.75   0.615      0.48   0.165      1.1530          0.502         0.2530
#
#       Shellweight  Rings   age
# 0.25        0.130    8.0   9.5
# 0.75        0.329   11.0  12.5

# %%
first = data.age.quantile(0.25)
second= data.age.quantile(0.75)
find = second-first
value = first - 1.5 * second
data.median(numeric_only=True)
# Out:
# Length            0.5450
# Diameter          0.4250
# Height            0.1400
# Wholweight        0.7995
# Shuckedweight     0.3360
# Visceraweight     0.1710
# Shellweight       0.2340
# Rings             9.0000
# age              10.5000
# dtype: float64

# %%
data['age'] = np.where(data['age'] < lower_limit, 7, data['age'])
sns.boxplot(x=data.age,showfliers = False)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def box_scatter(df, x, y):    
    fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(16,6))
    sns.boxplot(df=df, x=x, ax=ax1)
    sns.scatterplot(df=df, x=x,y=y,ax=ax2)
    box_scatter(data,'Diameter','Length');
print(" The Bivariate Outliers: {len(data.loc[data['Length'] < 0.6])}")
# Out:
#  The Bivariate Outliers: {len(data.loc[data['Length'] < 0.6])}

# %% [markdown]
# ### Check for Categorical columns and perform encoding

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
data.Sex = lab.fit_transform(data.Sex)

data.head()
# Out:
#    Sex  Length  Diameter  Height  Wholweight  Shuckedweight  Visceraweight  \
# 0    2   0.455     0.365   0.095      0.5140         0.2245         0.1010
# 1    2   0.350     0.265   0.090      0.2255         0.0995         0.0485
# 2    0   0.530     0.420   0.135      0.6770         0.2565         0.1415
# 3    2   0.440     0.365   0.125      0.5160         0.2155         0.1140
# 4    1   0.330     0.255   0.080      0.2050         0.0895         0.0395
#
#    Shellweight  Rings   age
# 0        0.150     15  16.5
# 1        0.070      7   8.5
# 2        0.210      9  10.5
# 3        0.155     10  11.5
# 4        0.055      7   8.5

# %% [markdown]
# ## Split the data into dependent and independent variables

# %%
y = data["Sex"]
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    1
# Name: Sex, dtype: int64

# %%
x=data.drop(columns=["Sex"],axis=1)
x.head()
# Out:
#    Length  Diameter  Height  Wholweight  Shuckedweight  Visceraweight  \
# 0      66        56   0.095      0.5140         0.2245         0.1010
# 1      45        36   0.090      0.2255         0.0995         0.0485
# 2      81        67   0.135      0.6770         0.2565         0.1415
# 3      63        56   0.125      0.5160         0.2155         0.1140
# 4      41        34   0.080      0.2050         0.0895         0.0395
#
#    Shellweight  Rings   age
# 0        0.150     15  16.5
# 1        0.070      7   8.5
# 2        0.210      9  10.5
# 3        0.155     10  11.5
# 4        0.055      7   8.5

# %% [markdown]
# ###  Scale the independent variables

# %%
from sklearn.preprocessing import scale
X_Scaled = pd.DataFrame(scale(x), columns=x.columns)
X_Scaled.head()
# Out:
#      Length  Diameter    Height  Wholweight  Shuckedweight  Visceraweight  \
# 0 -0.575145 -0.432329 -1.064424   -0.641898      -0.607685      -0.726212
# 1 -1.450298 -1.440444 -1.183978   -1.230277      -1.170910      -1.205221
# 2  0.049965  0.122135 -0.107991   -0.309469      -0.463500      -0.356690
# 3 -0.700167 -0.432329 -0.347099   -0.637819      -0.648238      -0.607600
# 4 -1.616994 -1.541255 -1.423087   -1.272086      -1.215968      -1.287337
#
#    Shellweight     Rings       age
# 0    -0.638217  1.571544  1.577830
# 1    -1.212987 -0.910013 -0.919022
# 2    -0.207139 -0.289624 -0.294809
# 3    -0.602294  0.020571  0.017298
# 4    -1.320757 -0.910013 -0.919022

# %% [markdown]
# ###  Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X_Scaled, y, test_size=0.2, random_state=0)

# %%
X_Train.shape,X_Test.shape
Y_Train.shape,Y_Test.shape
# Out:
# ((3341,), (836,))

# %%
X_Train.head()
# Out:
#         Length  Diameter    Height  Wholweight  Shuckedweight  Visceraweight  \
# 3141 -2.867214 -2.750993 -1.423087   -1.622870      -1.553902      -1.583867
# 3521 -2.575496 -2.599776 -2.020857   -1.606554      -1.551650      -1.565619
# 883   1.133488  1.231061  0.728888    1.145672       1.041436       0.286552
# 3627  1.591902  1.180655  1.446213    2.164373       2.661269       2.330326
# 2106  0.591727  0.474975  0.370226    0.432887       0.255175       0.272866
#
#       Shellweight     Rings       age
# 3141    -1.644065 -1.530402 -1.543234
# 3521    -1.626104 -2.150791 -1.387181
# 883      1.538726  1.571544  1.577830
# 3627     1.377072  0.020571  0.017298
# 2106     0.906479  1.261349  1.265723

# %%
X_Test.head()
# Out:
#         Length  Diameter    Height  Wholweight  Shuckedweight  Visceraweight  \
# 668   0.216661  0.172540  0.370226    0.181016      -0.368878       0.569396
# 1580 -0.200079 -0.079488 -0.466653   -0.433875      -0.443224      -0.343004
# 3784  0.800097  0.727004  0.370226    0.870348       0.755318       1.764639
# 463  -2.533822 -2.448559 -2.020857   -1.579022      -1.522362      -1.538247
# 2615  1.008466  0.928627  0.848442    1.390405       1.415417       1.778325
#
#       Shellweight     Rings       age
# 668      0.690940  0.951154  0.953617
# 1580    -0.325685 -0.599818 -0.606915
# 3784     0.565209  0.330765  0.329404
# 463     -1.572219 -1.530402 -1.543234
# 2615     0.996287  0.640960  0.641511

# %%
Y_Train.head()
# Out:
# 668     2
# 1580    1
# 3784    2
# 463     1
# 2615    2
# Name: Sex, dtype: int64

# %%
Y_Test.head()
# Out:
# 668     2
# 1580    1
# 3784    2
# 463     1
# 2615    2
# Name: Sex, dtype: int64

# %% [markdown]
# ## Build the model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10,criterion='entropy')

# %%
model.fit(X_Train,Y_Train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_predict = model.predict(X_Test)

# %%
y_predict_train = model.predict(X_Train)

# %% [markdown]
# ## Train the model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print('Training accuracy: ',accuracy_score(Y_Train,y_predict_train))
# Out:
# Training accuracy:  0.9835378629152948

# %% [markdown]
# ## Test the model

# %%
print('Testing accuracy: ',accuracy_score(Y_Test,y_predict))
# Out:
# Testing accuracy:  0.5251196172248804

# %% [markdown]
# ## Measure the performance using Metrics

# %%
pd.crosstab(Y_Test,y_predict)
# Out:
# col_0    0    1    2
# Sex
# 0      119   24  106
# 1       38  207   46
# 2      133   50  113

# %%
print(classification_report(Y_Test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.48      0.44       249
#            1       0.74      0.71      0.72       291
#            2       0.43      0.38      0.40       296
#
#     accuracy                           0.53       836
#    macro avg       0.52      0.52      0.52       836
# weighted avg       0.53      0.53      0.53       836
